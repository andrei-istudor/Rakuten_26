# %%
from __future__ import annotations

import hashlib
from pathlib import Path
import os, json
from datetime import datetime

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import re


from datasets import Dataset
from transformers import AutoTokenizer
import evaluate

from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.svm import LinearSVC
from sklearn.metrics import (
    accuracy_score,
    f1_score,
    classification_report,
    confusion_matrix,
)

# %%
DATA_DIR = Path("data")
# DATA_PATH = DATA_DIR / "rakuten_processed.csv"

# df = pd.read_csv(DATA_PATH)
# df.head()

# # Stratified split keeps class proportions similar in train and val
# train_df, val_df = train_test_split(
#     df,
#     test_size=0.2,
#     random_state=42,
#     stratify=df["prdtypecode"]
# )

# train_df.to_csv("train.csv")
# val_df.to_csv("test.csv")

# %%
# # save once again under a different name for fixing the split for longtime

# train_df.to_csv("train_fixed.csv", index=False)
# val_df.to_csv("test_fixed.csv", index=False)

# %%
# read the fixed and save only the label and three text columns and the productid

train_df = pd.read_csv(DATA_DIR / "train_fixed.csv")
val_df = pd.read_csv(DATA_DIR / "test_fixed.csv")

train_df = train_df[["text","text_stripped","text_stripped_lowercase","text_english","productid","prdtypecode"]]
val_df = val_df[["text","text_stripped","text_stripped_lowercase","text_english","productid","prdtypecode"]]

train_df.to_csv("train.csv", index=False)
val_df.to_csv("test.csv", index=False)
